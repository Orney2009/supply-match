# %% [markdown]
# # Installation

# %%
# !pip install nltk
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install wordcloud
# !pip install scikit-learn
# Out:
# Requirement already satisfied: nltk in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: click in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: pandas in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (2.1.3)
# Requirement already satisfied: wordcloud in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: scikit-learn in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/overwatch2009/anaconda3/lib/python3.13/site-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# # Importations

# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
from nltk import pos_tag
import pickle
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package english_wordnet to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package english_wordnet is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package mock_corpus to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package mock_corpus is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/overwatch2009/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %% [markdown]
# # Functions

# %%
def reader(filepath):
    df = pd.read_csv(filepath, encoding = 'utf8')    
    return df    

def tokenizer(df):
    try:
        tokenized_book = df
        tokenized_book["summary"] = df["summary"].map(lambda x: word_tokenize(x.lower() if isinstance(x, str) else str(x) ))
    except Exception as e:
        print("An error occurs when tokenizing")
    return tokenized_book

def stopwords_remover(df):    
    # with open("../utils/stopwords.txt") as file:
    #     custom_stopwords = file.read().split(",")
    try:   
        stop_words = set(stopwords.words('french'))    
        without_stopwords = df
        without_stopwords["summary"] = df["summary"].map(lambda x: [word for word in x if (word not in stop_words)]) 
    except Exception as e:
        print("An error occurs when removing stopwords")
    return without_stopwords

def punctuation_remover(df):
    try:
        punctuation = string.punctuation + "``" + "''" + "--" + "_" + "(" + ")" + '""' + "|" + "“" + "”" + "’" + "‘" + "___"
        without_punc = df
        without_punc["summary"] = df["summary"].map(lambda x: [word for word in x if word not in punctuation])
    except Exception as e:
        print("An error occurs when removing punctuations")
    return without_punc

def pos_tagger(df):
    try:
        pos_tagged = df
        pos_tagged["summary"] = df["summary"].map(lambda x: [tagged for tagged in pos_tag(x,tagset='universal') if tagged[1] not in ["NUM"] ])
    except Exception as e:
        print("An error occurs when tagging")
    return pos_tagged

def lemmatizer(df):
    try:
        lem = WordNetLemmatizer()
        lemmans = df
        lemmans["summary"] = df["summary"].map(lambda row: [ lem.lemmatize(word[0], pos = get_pos_tag(word[1])) for word in row ])
    except Exception as e:
        print("An error occurs when lemmatizing")
    return lemmans    

def get_pos_tag(pos):    
    match pos:
        case "NOUN":
            result = "n"
        case "VERB":
            result = "v"
        case "ADJ":
            result = "a"
        case "ADV":
            result = "r"
        case _:
            result = "s"
    return result

def search_processing(search, _vector, _lsa):
    try:
        search_df = pd.DataFrame(data=[search], columns=["summary"])
        tokenized_book = tokenizer(search_df)
        without_stopwords = stopwords_remover(tokenized_book)
        without_punctuation = punctuation_remover(without_stopwords)
        tagged_words = pos_tagger(without_punctuation)
        lemmatized_words = lemmatizer(tagged_words)

        vec = _vector.transform(lemmatized_words)
        return vec
        # return _lsa.transform(vec)

    except Exception as e:
        print(f"An error occurs when processing the search:{e}")
    
def best_recommended_pme(search, _vector, _lsa, topic_df, nb_recommandations):
    try:
        
        # Récupération du vecteur du livre cible
        search_vector = search_processing(search, _vector, _lsa)

        # Calcul des similarités cosinus
        similarities = topic_df.apply(
            lambda x: cosine_similarity(search_vector, x.to_numpy().reshape(1, -1))[0][0], axis=1
        )

        # Conversion en DataFrame
        recommandations = similarities.to_frame(name="Similarity")

        # Tri décroissant des similarités
        recommandations.sort_values(by="Similarity", ascending=False, inplace=True)

        # Sélection des meilleurs résultats
        result = recommandations.head(min(nb_recommandations, len(recommandations)))

        if result.empty:
            print("Aucune recommandation disponible.")
            return []

        print(f"Recommandations générées avec succès pour la recherche '{search}'.\n")
        return list(result.itertuples(index=True, name=None))
    
    except Exception as e:
        print(f"Une erreur est survenue lors de la génération des recommandations : {e}")
        return []


def words_frequency(df):    
    all_words = []    
    df["summary"].map(lambda row: all_words.extend(row))
    df["summary"] = pd.DataFrame({"words": all_words}).value_counts().reset_index()
    return df

def word_cloud(words_df, title):
    words_dict = dict(zip(words_df["words"], words_df["count"]))
    wc = WordCloud(width=800, height=400, background_color="white", max_words=100).generate_from_frequencies(words_dict)    
    plt.figure(figsize=(10,6))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(title)
    plt.savefig(title + ".png")
    plt.show()

def tf_idf_calculator(category, content):    
    try:
        vectorizer = TfidfVectorizer(strip_accents = "ascii", max_df = 0.6)
        m = vectorizer.fit_transform(content).transpose()
                
    except Exception as e:
       print("An error occurs when calculating terms frequency")
    return  (pd.DataFrame( data = m.toarray(), index = vectorizer.vocabulary_, columns = category), vectorizer)

# %%
try:
    dataset = reader("../data/processed/processed_data.csv")
except Exception as e:
    print(f"Une erreur est survenue lors de la lecture du dataset:\n{e}")

dataset
# Out:
#       Unnamed: 0                                               name  \
# 0              1                             GO AFRICA ONLINE - GAO
# 1              2                                           JAWUNTAA
# 2              3                                   JK COMMUNICATION
# 3              4                                      229 AdsSquare
# 4              5                                       2BME SERVICE
# ...          ...                                                ...
# 8469        8517                                SOLUTIONS DRIVE VTC
# 8470        8518                                 THIERRY BENIN TAXI
# 8471        8519                            AMBULANCES DES AMAZONES
# 8472        8520  SERVICE D'AIDE MEDICALE D'URGENCE DU BENIN - S...
# 8473        8521                                POLICE REPUBLICAINE
#
#                       category  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3     Agences de communication
# 4     Agences de communication
# ...                        ...
# 8469    Transports VTC - Taxis
# 8470    Transports VTC - Taxis
# 8471                Ambulances
# 8472                Ambulances
# 8473                    Police
#
#                                                 address                 tel  \
# 0     Lot 938 - 939, non loin de l'Etoile Rouge 04 B...  Tel:+2290169690406
# 1     Rue avant l'hôtel Bénin Royal, immeuble Golden...      +2290194710000
# 2     Bénin, Cotonou, Zogbo von Tornade ; deuxième r...      +2290153714272
# 3     BP 1541 Atlantique Department Abomey Calavi - ...      +2290196117373
# 4             2323 Atlantique Department Ouidah - Bénin      +2290160090917
# ...                                                 ...                 ...
# 8469                      Cotonou Cotonou - 229 - Bénin      +2290194613777
# 8470                                  - Cotonou - Bénin      +2290167814858
# 8471                     - Saint Michel Cotonou - Bénin      +2290141970704
# 8472        Ex-HIA Cotonou - 04 BP 1298 COTONOU - Bénin      +2290168300202
# 8473                              Ganhi Cotonou - Bénin  Tel:+2290121313480
#
#                                             description  \
# 0     Création de sites internet pour les profession...
# 1     Création; Production audiovisuelle; Média; Mar...
# 2     JK COMMUNICATION est spécialisé dans l’impress...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8469  Chauffeur Privé Fiable - Service de réservatio...
# 8470  Nous mettons à votre disposition notre véhicul...
# 8471                                                NaN
# 8472  Etablissement intervenant dans le pré-hospital...
# 8473                                                NaN
#
#                                                 summary
# 0     Création de sites internet pour les profession...
# 1     Création; Production audiovisuelle; Média; Mar...
# 2     JK COMMUNICATION est spécialisé dans l’impress...
# 3                              Agences de communication
# 4                              Agences de communication
# ...                                                 ...
# 8469  Transports VTC - TaxisChauffeur Privé Fiable -...
# 8470  Transports VTC - TaxisNous mettons à votre dis...
# 8471                                         Ambulances
# 8472  AmbulancesEtablissement intervenant dans le pr...
# 8473                                             Police
#
# [8474 rows x 7 columns]

# %% [markdown]
# # Word Cloud

# %%
# books_words_list = []
try:
    tokenized_book = tokenizer(dataset)
    without_stopwords = stopwords_remover(tokenized_book)
    without_punctuation = punctuation_remover(without_stopwords)
    tagged_words = pos_tagger(without_punctuation)
    lemmatized_words = lemmatizer(tagged_words)
    
except Exception as e:
    print(f"Une erreur est survenue lors du traitement du corpus : {e}")

# %% [markdown]
# # Topic Modeling

# %%
try:
    # Calcul du TF-IDF
    text = [" ".join(str(elm) for elm in desc) for desc in dataset["summary"].tolist()]
    categories = dataset["name"].to_list()
    document_term_matrix, vector = tf_idf_calculator(categories, text)
    print("TF-IDF calculé avec succès")

except Exception as e:
    print(f"Échec du calcul TF-IDF : {e}")
# Out:
# TF-IDF calculé avec succès

# %%
document_term_matrix
# Out:
#                 GO AFRICA ONLINE - GAO  JAWUNTAA  JK COMMUNICATION  \
# creation                           0.0       0.0               0.0
# site                               0.0       0.0               0.0
# internet                           0.0       0.0               0.0
# professionnels                     0.0       0.0               0.0
# africains                          0.0       0.0               0.0
# ...                                ...       ...               ...
# avises                             0.0       0.0               0.0
# declenchement                      0.0       0.0               0.0
# relative                           0.0       0.0               0.0
# informatise                        0.0       0.0               0.0
# police                             0.0       0.0               0.0
#
#                 229 AdsSquare  2BME SERVICE  ADHERE Digital  \
# creation                  0.0           0.0             0.0
# site                      0.0           0.0             0.0
# internet                  0.0           0.0             0.0
# professionnels            0.0           0.0             0.0
# africains                 0.0           0.0             0.0
# ...                       ...           ...             ...
# avises                    0.0           0.0             0.0
# declenchement             0.0           0.0             0.0
# relative                  0.0           0.0             0.0
# informatise               0.0           0.0             0.0
# police                    0.0           0.0             0.0
#
#                 ADJINANKOU GROUP - Agence de Communication à Cotonou  \
# creation                                                      0.0
# site                                                          0.0
# internet                                                      0.0
# professionnels                                                0.0
# africains                                                     0.0
# ...                                                           ...
# avises                                                        0.0
# declenchement                                                 0.0
# relative                                                      0.0
# informatise                                                   0.0
# police                                                        0.0
#
#                 AFRIKAFUN  AFRIQIYA GROUP  AGENCE LES JUMEAUX  ...  \
# creation              0.0             0.0                 0.0  ...
# site                  0.0             0.0                 0.0  ...
# internet              0.0             0.0                 0.0  ...
# professionnels        0.0             0.0                 0.0  ...
# africains             0.0             0.0                 0.0  ...
# ...                   ...             ...                 ...  ...
# avises                0.0             0.0                 0.0  ...
# declenchement         0.0             0.0                 0.0  ...
# relative              0.0             0.0                 0.0  ...
# informatise           0.0             0.0                 0.0  ...
# police                0.0             0.0                 0.0  ...
#
#                 GROUPE EYON  OCTAVIC-BENIN  OLINEBENIN  SOFT TAXIS  \
# creation                0.0            0.0         0.0         0.0
# site                    0.0            0.0         0.0         0.0
# internet                0.0            0.0         0.0         0.0
# professionnels          0.0            0.0         0.0         0.0
# africains               0.0            0.0         0.0         0.0
# ...                     ...            ...         ...         ...
# avises                  0.0            0.0         0.0         0.0
# declenchement           0.0            0.0         0.0         0.0
# relative                0.0            0.0         0.0         0.0
# informatise             0.0            0.0         0.0         0.0
# police                  0.0            0.0         0.0         0.0
#
#                 SOLA DRIVE COMPANY  SOLUTIONS DRIVE VTC  THIERRY BENIN TAXI  \
# creation                       0.0                  0.0                 0.0
# site                           0.0                  0.0                 0.0
# internet                       0.0                  0.0                 0.0
# professionnels                 0.0                  0.0                 0.0
# africains                      0.0                  0.0                 0.0
# ...                            ...                  ...                 ...
# avises                         0.0                  0.0                 0.0
# declenchement                  0.0                  0.0                 0.0
# relative                       0.0                  0.0                 0.0
# informatise                    0.0                  0.0                 0.0
# police                         0.0                  0.0                 0.0
#
#                 AMBULANCES DES AMAZONES  \
# creation                            0.0
# site                                0.0
# internet                            0.0
# professionnels                      0.0
# africains                           0.0
# ...                                 ...
# avises                              0.0
# declenchement                       0.0
# relative                            0.0
# informatise                         0.0
# police                              0.0
#
#                 SERVICE D'AIDE MEDICALE D'URGENCE DU BENIN - SAMU BENIN  \
# creation                                                      0.0
# site                                                          0.0
# internet                                                      0.0
# professionnels                                                0.0
# africains                                                     0.0
# ...                                                           ...
# avises                                                        0.0
# declenchement                                                 0.0
# relative                                                      0.0
# informatise                                                   0.0
# police                                                        0.0
#
#                 POLICE REPUBLICAINE
# creation                        0.0
# site                            0.0
# internet                        0.0
# professionnels                  0.0
# africains                       0.0
# ...                             ...
# avises                          0.0
# declenchement                   0.0
# relative                        0.0
# informatise                     0.0
# police                          0.0
#
# [10696 rows x 8474 columns]

# %% [markdown]
# # LSA

# %%
try:
    # Vérification de la matrice TF-IDF
    if document_term_matrix is None:
        raise ValueError("La matrice TF-IDF est vide ou non définie.")
    if not hasattr(document_term_matrix, "shape"):
        raise TypeError("document_term_matrix n'est pas une matrice valide.")
    if document_term_matrix.shape[0] == 0 or document_term_matrix.shape[1] == 0:
        raise ValueError(f"Matrice TF-IDF vide : {document_term_matrix.shape}")

    # Application du modèle LSA
    nb_cat = len(dataset["category"].value_counts())
    lsa = TruncatedSVD(n_components=nb_cat)
    document_vectors = lsa.fit_transform(document_term_matrix.transpose())

    # Vérification des tailles
    
    # Création du DataFrame
    topic_columns = [f"Topic {i+1}" for i in range(nb_cat)]
    topic_df = pd.DataFrame(
        document_vectors,
        columns=topic_columns,
        index=dataset["name"].to_list()
    )

    print(f"Réduction LSA effectuée avec succès.")
    display(topic_df)

except Exception as e:
    print(f"Impossible d’effectuer la réduction LSA : {e}")
# Out:
# Réduction LSA effectuée avec succès.
#                                                          Topic 1  \
# GO AFRICA ONLINE - GAO                              1.411474e-02
# JAWUNTAA                                            1.932045e-02
# JK COMMUNICATION                                    1.659502e-02
# 229 AdsSquare                                       1.342433e-02
# 2BME SERVICE                                        1.342433e-02
# ...                                                          ...
# SOLUTIONS DRIVE VTC                
# SERVICE D'AIDE MEDICALE D'URGENCE DU BENIN - SA...   0.047354   0.044268
# POLICE REPUBLICAINE                                 -0.000022  -0.000191
#
#                                                     Topic 484  Topic 485  \
# GO AFRICA ONLINE - GAO                               0.011764  -0.021601
# JAWUNTAA                                             0.045433  -0.015848
# JK COMMUNICATION                                    -0.015658  -0.019605
# 229 AdsSquare                                        0.001398   0.000491
# 2BME SERVICE                                         0.001398   0.000491
# ...                                                       ...        ...
# SOLUTIONS DRIVE VTC                                  0.022299   0.001423
# THIERRY BENIN TAXI                                   0.037970  -0.027633
# AMBULANCES DES AMAZONES                             -0.000683   0.000195
# SERVICE D'AIDE MEDICALE D'URGENCE DU BENIN - SA...   0.050063  -0.057093
# POLICE REPUBLICAINE                                 -0.001138  -0.000107
#
#                                                     Topic 486  Topic 487
# GO AFRICA ONLINE - GAO                               0.007331   0.037518
# JAWUNTAA                                             0.005798   0.011731
# JK COMMUNICATION                                     0.045848   0.019303
# 229 AdsSquare                                       -0.003438  -0.001463
# 2BME SERVICE                                        -0.003438  -0.001463
# ...                                                       ...        ...
# SOLUTIONS DRIVE VTC                                 -0.019534   0.016497
# THIERRY BENIN TAXI                                   0.033686   0.036886
# AMBULANCES DES AMAZONES                             -0.000545   0.000144
# SERVICE D'AIDE MEDICALE D'URGENCE DU BENIN - SA...  -0.008377   0.044730
# POLICE REPUBLICAINE                                 -0.000761  -0.000305
#
# [8474 rows x 487 columns]

# %% [markdown]
# # Models exportation

# %%
# lsa model export
with open('../pickles/lsa_model.pkl', 'wb') as lsa_model:
    pickle.dump(lsa, lsa_model)                    


# vector export
with open('../pickles/vector.pkl', 'wb') as vector_pkl:    
    pickle.dump(vector, vector_pkl)

# %%
try:
    # Vérification des objets nécessaires
    if 'lsa' not in locals() or lsa is None:
        raise ValueError("L'objet LSA (TruncatedSVD) n'existe pas ou n'a pas été entraîné.")
    if 'vector' not in locals() or vector is None:
        raise ValueError("Le vecteur TF-IDF (vectorizer) n'est pas défini.")
    if not hasattr(lsa, "components_"):
        raise AttributeError("L'objet LSA ne contient pas d'attribut 'components_'. Avez-vous bien appelé fit_transform() ?")

    # Extraction du vocabulaire
    vocab = vector.get_feature_names_out()
    if len(vocab) == 0:
        raise ValueError("Le vocabulaire TF-IDF est vide. Vérifiez vos données d'entrée.")

    # Affichage des mots les plus représentatifs par thème
    print("=== Mots les plus représentatifs par thème (LSA) ===\n")

    for i, comp in enumerate(lsa.components_):
        vocab_comp = list(zip(vocab, comp))

        if not vocab_comp:
            print(f"Aucun mot trouvé pour le Topic {i+1}.")
            continue

        # Tri des mots les plus importants
        sorted_words = sorted(vocab_comp, key=lambda x: x[1], reverse=True)[:10]

        print(f"Topic {i+1} :")
        print(" ".join([word for word, _ in sorted_words]))
        print()  # saut de ligne

    print("Interprétation des topics terminée avec succès.")

except Exception as e:
    print(f"Une erreur est survenue lors de l'interprétation des topics : {e}")
# Out:
# === Mots les plus représentatifs par thème (LSA) ===
#
# Topic 1 :
# informatique formation securite maintenance materiel ingenierie centre bureautique materiels equipements
#
# Topic 2 :
# produits materiels centre equipements medicaux agences agricoles location cosmetiques reception
#
# Topic 3 :
# agences immobilieres voyage communication recrutement developpement maritimes immigration douane appui
#
# Topic 4 :
# centre medicaux commerciaux sociaux formation culturels cabinet recherche loisirs coworking
#
# Topic 5 :
# produits centre cosmetiques pharmaceutiques congeles surgeles commerciaux phytosanitaires dietetiques formation
#
# Topic 6 :
# ecoles secondaires auto primaires technique transport bureau fournitures enseignement general
#
# Topic 7 :
# transport bureau routier maritime fournitures shipping change mobilier logistiques conseils
#
# Topic 8 :
# bureau fournitures change mobilier consultant etudes conseils scolaires vente construction
#
# Topic 9 :
# construction vente materiaux centre voitures location fabrication peinture metalliques alimentation
#
# Topic 10 :
# cabinet construction medicaux alimentation avocats dentistes dentaires materiaux vente grossistes
#
# Topic 11 :
# alimentation grossistes generale distributeurs animale garage mecanique materiels centre reception
#
# Topic 12 :
# textile vente voitures fabrication tissus location peinture cabinet cycle motos
#
# Topic 13 :
# textile tissus securite construction materiels materiaux equipements electronique incendie gardiennage
#
# Topic 14 :
# securite electronique incendie gardiennage vente fabrication conseil peinture cycle motos
#
# Topic 15 :
# laboratoires photographiques analyses medicales btp association vente ecole fabrication conseil
#
# Topic 16 :
# association professionnelles ecole maternelle conseil expertise assurance comptable langue formation
#
# Topic 17 :
# ecole maternelle langue mode accessoires couture formation salon matelas mousse
#
# Topic 18 :
# assurance conseil location expertise reception comptable gestion courtier cabinet audit
#
# Topic 19 :
# assurance courtier equipements materiels vente industriels agricoles fabrication menuiserie aluminium
#
# Topic 20 :
# assurance securite location association laboratoires construction courtier voitures reception ecole
#
# Topic 21 :
# salon beaute esthetique coiffure menuiserie aluminium bois the location reception
#
# Topic 22 :
# menuiserie aluminium bois location reception scieries securite cabinet salles assurance
#
# Topic 23 :
# import export genie civil electrique electriciens evenementiel eau batiment travaux
#
# Topic 24 :
# expertise comptable financiere medicaux sociaux immobiliere location controle equipements voitures
#
# Topic 25 :
# enfants bebes boutique creche jardin expertise comptable art galerie cabinet
#
# Topic 26 :
# medicaux import export conseil sociaux equipements audit juridique fiscal location
#
# Topic 27 :
# genie civil medicaux eau forage electrique electriciens sociaux location equipements
#
# Topic 28 :
# eau forage adduction import export minerale art production galerie medicaux
#
# Topic 29 :
# pharmacy veterinaires eau forage materiel adduction import export minerale production
#
# Topic 30 :
# art galerie gestion ressources humaines medicaux immobiliere formation graphique equipements
#
# Topic 31 :
# art galerie graphique conseil expertise comptable genie fabrication civil audit
#
# Topic 32 :
# automobile moto concessionnaires lavage art galerie graphique conseil expertise comptable
#
# Topic 33 :
# generale garage mecanique alimentation froid climatisation sport club animale batiment
#
# Topic 34 :
# bar restaurant sport club maquis magasins gym discotheques night salles
#
# Topic 35 :
# sport club magasins gym discotheques night salles fitness formation organismes
#
# Topic 36 :
# consulats ambassades proche loisirs hote restaurantschambre rita cher aeroport affaires
#
# Topic 37 :
# generalistes medecins organismes internationaux anglais evenementiel english cours credit avance
#
# Topic 38 :
# ministeres plastique offrons voiture cosmetiquecosmetique pneus pneumatiquesvente sous chaussuresvente carrosserie
#
# Topic 39 :
# auberge ministeres offre traiteur personnes specialiste routiere chaussuresvente international bio
#
# Topic 40 :
# organismes internationaux credit formation evenementiel interieur decoration bureautique architectes professionnelle
#
# Topic 41 :
# evenementiel interieur decoration architectes formation pret porter production batiment travaux
#
# Topic 42 :
# evenementiel gestion ressources humaines sport club immobiliere eau genie generale
#
# Topic 43 :
# immobilier evenementiel batiment travaux public maintenance froid energie climatisation quincaillerie
#
# Topic 44 :
# immobilier interieur architectes decoration gestion immobiliere ressources humaines btp commerciaux
#
# Topic 45 :
# polycliniques cliniques restaurant interieur immobilier architectes decoration gestion ressources humaines
#
# Topic 46 :
# huissiers justice restaurant batiment travaux public maintenance commerciaux plomberie froid
#
# Topic 47 :
# restaurant interieur travaux batiment public architectes decoration maintenance commerciaux industry
#
# Topic 48 :
# restaurant porter pret immobilier accessoires chaussures couture mode genie industry
#
# Topic 49 :
# formation immobilier bureautique professionnelle huissiers justice restaurant tourisme equipements medicaux
#
# Topic 50 :
# industry bois immobilier negoce bar gestion menuiserie interieur hotels architectes
#
# Topic 51 :
# quincaillerie industry porter pret travaux public batiment vitrerie miroiterie evenementiel
#
# Topic 52 :
# microfinance quincaillerie negoce transit maritime fret consignation hopitauxsante publique education
#
# Topic 53 :
# telephonie mobile quincaillerie accessoires electromenagers appareils bois transferts matelas fonds
#
# Topic 54 :
# gynecologue carrosserie agronomie animaux pharmaceutique interne hotellerie audiovisuelle scolaire vehicule
#
# Topic 55 :
# fabrication travaux public meches batiment perruques aluminium telephonie mobile peinture
#
# Topic 56 :
# accessoires matelas mousse literie appareils electromenagers plomberie mode fabrication meches
#
# Topic 57 :
# fabrication meches perruques froid energie climatisation bois peinture maintenance solaire
#
# Topic 58 :
# notaires marche toute base offre expertises public design travers meilleur
#
# Topic 59 :
# consignation maritime transit entreposage manutention negoce logistique shipping bois expert
#
# Topic 60 :
# plomberie bois formation menuiserie consignation bureautique voitures btp scieries cycle
#
# Topic 61 :
# miroiterie vitrerie appareils electromenagers aluminium plomberie froid climatisation consignation friperies
#
# Topic 62 :
# appareils electromenagers bois public batiment travaux friperies chaussures formation menuiserie
#
# Topic 63 :
# hotels hopitaux plomberie froid climatisation nettoyage industriel miroiterie vitrerie service
#
# Topic 64 :
# energie solaire renouvelable appareils electromenagers hotels hopitaux boulangeries patisseries developpement
#
# Topic 65 :
# boulangeries patisseries froid climatisation plomberie miroiterie vitrerie patisseriespatisserie production pieces
#
# Topic 66 :
# hopitaux miroiterie vitrerie societes developpement appui pieces financement production detachees
#
# Topic 67 :
# hopitaux energie aluminium froid climatisation solaire renouvelable bureautique formation consignation
#
# Topic 68 :
# aluminium societes financement reseaux telecommunication developpement bourse appui plomberie informatiques
#
# Topic 69 :
# soudeurs supermarches chaussuresvente savonnerie application occasion traiteur culture creation type
#
# Topic 70 :
# supermarches investissement marbrerie ainsi specialiste carreaux design plan plusieurs instruments
#
# Topic 71 :
# societes financement bourse froid climatisation energie fonds bois transferts solaire
#
# Topic 72 :
# negoce pieces detachees aluminium commerce general production serigraphie transit service
#
# Topic 73 :
# negoce telecommunication reseaux chaussures societes froid financement friperies climatisation bois
#
# Topic 74 :
# chaussures friperies pieces detachees chaussuresvente plomberie aluminium froid sacs chaussuresventes
#
# Topic 75 :
# pieces detachees telecommunication reseaux bureautique fournitures societes negoce librairie electromenagers
#
# Topic 76 :
# pneumatiques librairie pieces detachees fournitures negoce telecommunication societes depannage reseaux
#
# Topic 77 :
# librairie papeterie fournitures couture atelier serigraphie scolaires chaussures numerique impression
#
# Topic 78 :
# friperies transferts fonds couture atelier pneumatiques serigraphie developpement froid appui
#
# Topic 79 :
# transferts fonds chaussures librairie serigraphie commerce impression numerique general argent
#
# Topic 80 :
# couture atelier fournitures maintenance chaussures depannage scolaires industrielle electronique fast
#
# Topic 81 :
# pediatrie commerce general pneumatiques btp materiels froid medicaux climatisation chambres
#
# Topic 82 :
# couture atelier developpement librairie appui pneumatiques conseils consultant froid etudes
#
# Topic 83 :
# pressing nettoyage pneumatiques industriel entretien btp telecommunication reseaux transit developpement
#
# Topic 84 :
# serigraphie impression numerique pneumatiques froid btp climatisation enseignes materiel lumineuses
#
# Topic 85 :
# papeterie fournitures commerce lubrifiants production general pneumatiques btp scolaires distribution
#
# Topic 86 :
# papeterie developpement appui serigraphie fournitures bureaux projets maintenance depannage negoce
#
# Topic 87 :
# cave vin btp depannage maintenance commerce developpement electronique general appui
#
# Topic 88 :
# fast food equipements agricoles cave vin production industriels commerciaux voitures
#
# Topic 89 :
# papeterie lubrifiants conseils consultant etudes equipements production agricoles ingenieurs informatiques
#
# Topic 90 :
# fast food papeterie btp conseils consultant commerce etudes general depannage
#
# Topic 91 :
# maquis papeterie commerce maquiscafe general conseils service consultant maritime transit
#
# Topic 92 :
# lubrifiants maquis fast food developpement appui depannage serigraphie maintenance bureautique
#
# Topic 93 :
# ameublement commerce general equipements serigraphie agricoles lubrifiants telecommunication appui industriels
#
# Topic 94 :
# ophtalmologues merceries agronomie plastique traiteur electrique creation huiles hygiene depuis
#
# Topic 95 :
# merceries financier multimedias orl personnes routiere plan laitiers faisons digital
#
# Topic 96 :
# telecommunications commerce general transit maritime equipements lubrifiants agricoles shipping informatiques
#
# Topic 97 :
# telecommunications bureautique btp numerique impression informatiques consommables ameublement consultant studio
#
# Topic 98 :
# transit maritime shipping entreposage manutention bureautique informatiques expert consommables numerique
#
# Topic 99 :
# bureautique informatiques consommables numerique impression consultant conseils commerce general etudes
#
# Topic 100 :
# bureautique serigraphie production distribution electricite studio conseils photo video consultant
#
# Topic 101 :
# informatiques consommables fournitures serigraphie scolaires formation tourisme consultant sante architectes
#
# Topic 102 :
# architectes numerique impression voitures production ameublement matelas tourisme mousse studio
#
# Topic 103 :
# cybercafes offrons orl genre education chaussuresvente promotion plastique personnes but
#
# Topic 104 :
# poissonnerie cybercafes agronomie personnes cartographie carreaux marchandises specialiste financier laitiers
#
# Topic 105 :
# voitures btp tourisme meches perruques club fabrication alarmes location fournitures
#
# Topic 106 :
# enseignement superieur universite voitures btp primaire maternel fournitures universiteenseignement meches
#
# Topic 107 :
# regie publicitaire informatiques cadeaux objets consommables publicitaires photo video entreposage
#
# Topic 108 :
# entreposage manutention routier transport representation informatiques commerciale hydrocarbure consommables petrole
#
# Topic 109 :
# parfumeries beaute parfumeriesvente accessoire esthetique ameublement cosmetique sante commerce general
#
# Topic 110 :
# tourisme bureautique sante courrier nettoyage industriel office materiel commerciaux service
#
# Topic 111 :
# traiteurs cuisinesdraissage plateau specialite salade formation stylismes voitures professionnelle commerce
#
# Topic 112 :
# hydrocarbure petrole stylismes petroliers transit nettoyage industriel distribution regie publicitaire
#
# Topic 113 :
# stylismes tourisme bureautique sante nettoyage materiel industriel courrier express commerciaux
#
# Topic 114 :
# sante nettoyage industriel logistique courrier express service gaz benin assainissement
#
# Topic 115 :
# administration nettoyage industriel gaz informatiques consommables banques entretien courrier mobilier
#
# Topic 116 :
# administration sante conseils fournitures etudes ingenieurs consultant maritime scolaires climatisation
#
# Topic 117 :
# conseils fournitures etudes consultant ingenieurs scolaires photo studio nettoyage ingenierie
#
# Topic 118 :
# logistique courrier express pharmaceutiques representation commerciale administration gaz climatisation froid
#
# Topic 119 :
# congeles surgeles logistique courrier alimentation express animale entreposage manutention btp
#
# Topic 120 :
# imprimeries photo studio video sante pharmaceutiques nettoyage garage mecanique banques
#
# Topic 121 :
# photo studio video sante pharmaceutiques garage mecanique distributeurs banques surveillance
#
# Topic 122 :
# banques logistique cosmetiques production alimentation distribution electricite huile animale commercialisation
#
# Topic 123 :
# gaz courrier banques express sante maritime photo studio video shipping
#
# Topic 124 :
# opticiens orl systeme public multimedias bio alarme metallurgique accompagnement photographie
#
# Topic 125 :
# representation commerciale congeles gaz surgeles logistique pharmaceutiques agricoles garage mecanique
#
# Topic 126 :
# logistique gaz cosmetiques photo studio video veterinaires alimentation entreposage assainissement
#
# Topic 127 :
# veterinaires representation commerciale alimentation materiel photo video cosmetiques studio electronique
#
# Topic 128 :
# veterinaires materiel pharmaceutiques garage mecanique production distributeurs electricite distribution grossistes
#
# Topic 129 :
# auto primaires ecoles parc transit conseils commerce consultant superieur universite
#
# Topic 130 :
# assainissement canalisation pharmaceutiques alimentation animale maritime agricoles shipping production creche
#
# Topic 131 :
# assainissement canalisation cosmetiques distributeurs garage mecanique grossistes representation commerciale auto
#
# Topic 132 :
# transit routier transport canalisation assainissement logistiques secondaires pharmaceutiques climatisation alimentation
#
# Topic 133 :
# magazine presse journaux service cadeaux objets internet publicitaires bijouterie joaillerie
#
# Topic 134 :
# bijouterie joaillerie cadeaux objets publicitaires boutique bebes service internet immobiliers
#
# Topic 135 :
# bijouterie joaillerie magazine journaux presse logistique industriel nettoyage sante production
#
# Topic 136 :
# creche jardin agricoles joaillerie bijouterie cadeaux objets publicitaires btp studio
#
# Topic 137 :
# alarmes surveillance creche jardin internet joaillerie bijouterie cosmetiques groupe electrogene
#
# Topic 138 :
# promoteurs immobiliers agricoles btp service bebes boutique photographes professionnels immobiliere
#
# Topic 139 :
# promoteurs immobiliers cadeaux objets publicitaires alarmes logistique cosmetiques surveillance sante
#
# Topic 140 :
# agricoles alarmes surveillance btp intrants electronique sociaux distributeurs cadeaux depannage
#
# Topic 141 :
# interpretes traducteurs agricoles alarmes surveillance electronique cadeaux objets publicitaires promoteurs
#
# Topic 142 :
# residence alarmes materiel electronique surveillance depannage production agricoles logistique industriel
#
# Topic 143 :
# electrogene groupe veterinaires maintenance agricoles ingenierie incendie avocats gardiennage securite
#
# Topic 144 :
# electrogene groupe photographes professionnels materiel agricoles sante photographiques electronique btp
#
# Topic 145 :
# avocats ong materiel gouvernementales organisation non electrogene groupe electronique analyses
#
# Topic 146 :
# avocats commerciaux photographes cabinet professionnels sante veterinaires maintenance analyses medicales
#
# Topic 147 :
# internet medicales analyses materiel electriques acces fournisseur sociaux electronique materiels
#
# Topic 148 :
# photographes professionnels analyses medicales agricoles electriques veterinaires ingenierie sociaux dentistes
#
# Topic 149 :
# cosmetique industrie cycle motos ingenierie meches agro analyses medicales perruques
#
# Topic 150 :
# radio cosmetique industrie cycle ingenierie motos meches agro analyses medicales
#
# Topic 151 :
# boissons materiel cosmetique service boissonsdistribution maintenance marketing prestation medicales analyses
#
# Topic 152 :
# boissons internet ingenierie photographes electronique acces fournisseur professionnels electrogene groupe
#
# Topic 153 :
# fondations materiaux materiel cosmetique electriques controle ouvrages beton boissons medicales
#
# Topic 154 :
# mode accessoires tissus meches cycle motos perruques materiel modevente vetements
#
# Topic 155 :
# ingenierie electronique marketing commerciaux peinture depannage mobilier medicales analyses groupe
#
# Topic 156 :
# change marketing photographiques meches cycle ingenierie motos perruques service electronique
#
# Topic 157 :
# change peinture cosmetique photographiques vente enseignes electriques culturels lumineuses beaute
#
# Topic 158 :
# commerciaux change btp medicales analyses coiffure immobiliere maintenance medicaux internet
#
# Topic 159 :
# coiffure salon cosmetique the culturels peinture industrie photographiques electriques recherche
#
# Topic 160 :
# marketing communication photographes internet cosmetique professionnels electriques logistique digital photographiques
#
# Topic 161 :
# travail temporaire interim ressources humaines recrutement medecine traditionnelle comptable btp
#
# Topic 162 :
# commerciaux electriques fret photographiques materiels medicaux enseignes sociaux lumineuses agricoles
#
# Topic 163 :
# fret marketing immobilieres btp culturels equipements aerien internet salles avocats
#
# Topic 164 :
# enseignes lumineuses fret gravure cycle motos btp meches perruques communication
#
# Topic 165 :
# immobilieres travail temporaire interim enseignes lumineuses marketing immobiliere medecine change
#
# Topic 166 :
# conditionnement emballage emballages agroalimentaire humaines ressources marketing conditionnementemballages electriques agro
#
# Topic 167 :
# carrelage conditionnement emballage immobilieres entretien quincailleriepeinture service carrelagetouts prestation carreaux
#
# Topic 168 :
# artisanat epiceries humaines ressources achatsvente necessites issus centrales carrelage premieres
#
# Topic 169 :
# immobiliere travail temporaire interim voyage gestion medecine civil traditionnelle fret
#
# Topic 170 :
# serrureries cafe specialiste chaussuresvente article table telecommunication conception personnes veterinaire
#
# Topic 171 :
# startup communication coworking ligne industrie fret web primaires espace collaboratif
# dietetiques ingenieurs huile entretien douane commercialisation produits elevage maritimes conseils
#
# Topic 206 :
# douane commissionnaires maritimes ingenieurs phytosanitaires concassage routier carriere projets bureaux
#
# Topic 207 :
# concassage carriere comptable sable agriculture incendie exploitation magasins sport metalliques
#
# Topic 208 :
# demenagement meubles garde comptable routier incendie loisirs ciment maritimes vente
#
# Topic 209 :
# ingenieurs environnement conseils demenagement meubles garde maritimes consommables change juridique
#
# Topic 210 :
# maritimes environnement consultant audit financiere etudes projets bureaux dietetiques demenagement
#
# Topic 211 :
# environnement douane demenagement meubles garde commissionnaires recherche dietetiques consultant recrutement
#
# Topic 212 :
# loisirs financiere controle exploitation salles electriques technique lieux expertise dietetiques
#
# Topic 213 :
# recherche electriques ingenieurs salles financiere exploitation discotheques night lieux audit
#
# Topic 214 :
# exploitation financiere magasins forestiere ciment reception sport miniere agriculture ligne
#
# Topic 215 :
# epargne exploitation credit forestiere miniere comptable maritimes agriculture coton loisirs
#
# Topic 216 :
# exploitation forestiere comptable miniere maritimes electriques coton benin salles agriculture
#
# Topic 217 :
# boucheries agriculture orl representants chaussuresvente bio menuiserie occasion electrique hygiene
#
# Topic 218 :
# broderies boucheries article agronomie machine cosmetiquecosmetique achats porte plant offrant
#
# Topic 219 :
# elevage exploitation aquaculture pisciculture forestiere bois miniere scieries alimentaires complements
#
# Topic 220 :
# menuiserie exploitation industrielle financiere forestiere miniere elevage galerie controle informatique
#
# Topic 221 :
# graphique elevage art menuiserie sociaux web ingenieurs industriels financiere creation
#
# Topic 222 :
# aquaculture pisciculture graphique dietetiques ciment industrie agriculture pisciculturenous poisson fruit
#
# Topic 223 :
# sonorisation eclairage musique musiquevente instrument menuiserie electronique credit galerie instruments
#
# Topic 224 :
# credit organismes demenagement meubles garde logistiques financiere graphique creditepargne aquaculture
#
# Topic 225 :
# office nationaux credit parcs elevage organismes depannage graphique telephone sonorisation
#
# Topic 226 :
# alimentaires complements affaires coworking aquaculture pisciculture sociaux sonorisation depannage eclairage
#
# Topic 227 :
# depannage loisirs telephone portable electroniquereparation recherche sonorisation graphique jeux eclairage
#
# Topic 228 :
# alimentaires complements loisirs aquaculture pisciculture recherche graphique maintenance electronique ingenierie
#
# Topic 229 :
# sociaux controle industriels avocats technique entretien inspection qualite medias salles
#
# Topic 230 :
# entretien affaires coworking controle route signalisation graphique installation deratisation desinsectisation
#
# Topic 231 :
# lingerie controle technique tissus affaires coworking inspection qualite complements alimentaires
#
# Topic 232 :
# lingerie entretien financiere tissus assistance sociaux management adduction industriels sociale
#
# Topic 233 :
# cardiologues commissionnaires achat espace plastique camion livraison projet homme instrument
#
# Topic 234 :
# adduction eau minerale controle tissus metalliques technique alimentaires complements entreprise
#
# Topic 235 :
# tissus agro forage textilesdistribution financiere langue industrie confection vetements textilesvente
#
# Topic 236 :
# management leadership controle tissus comptable juridique entretien fiscal technique adduction
#
# Topic 237 :
# musique musiquevente instrument instruments direction nationales industrielle musiqueecole musiquefabrication music
#
# Topic 238 :
# bourse jeux professionnelles jouets societes menuiserie port appui maintenance jouetssalle
#
# Topic 239 :
# jeux financement professionnelles jouets menuiserie port jouetssalle maintenance management portable
#
# Topic 240 :
# professionnelles port ouvre filiere savoir faire excellence management depannage medias
#
# Topic 241 :
# medias jeux publicite recherche jouets entretien maritimes bourse affaires coworking
#
# Topic 242 :
# direction nationales professionnelles menuiserie port telephone depannage electroniquereparation portable eclairage
#
# Topic 243 :
# funebres pompes technologie appliquee installation menuiserie electroniquereparation telephone portable web
#
# Topic 244 :
# sanitaires funebres pompes industrielle professionnelles aliment sanitaire benin tuyauterie scieries
#
# Topic 245 :
# technologie appliquee web sanitaires menuiserie site telephone electroniquereparation portable solution
#
# Topic 246 :
# ebenisterie technologie appliquee industrielle jeux tuyauterie scieries professionnelles bois jouets
#
# Topic 247 :
# ebenisterie menuiserie professionnelle maintenance gardiennage telephone portable ingenierie electroniquereparation incendie
#
# Topic 248 :
# geometres egalement application design toute vetements offre cosmetiquecosmetique instrument agricole
#
# Topic 249 :
# the salon benin and of appliquee technologie to entretien be
#
# Topic 250 :
# epiceries ciment fine shipping benin appliquee technologie epices societe maintenance
#
# Topic 251 :
# epiceries logistiques fine expert epices ligne industrielle web maritime routier
#
# Topic 252 :
# logistiques benin expert appliquee technologie industriels maritime ciment maintenance routier
#
# Topic 253 :
# logistiques specialisee entreprise ciment courtier expert desinsectisation deratisation desinfection solaire
#
# Topic 254 :
# courtier chambres electriques commerce animale installation magasins entretien societe hotes
#
# Topic 255 :
# courtier desinsectisation deratisation desinfection benin gym fitness materiels shipping ligne
#
# Topic 256 :
# chambres desinsectisation deratisation desinfection assurance ligne commerce hotes generale professionnelle
#
# Topic 257 :
# animale mecanique garage desinsectisation deratisation desinfection societe grossistes production viande
#
# Topic 258 :
# commissaires industriels comptes chambres electriques ciment incendie lieux cabinet magasins
#
# Topic 259 :
# commissaires comptes chambres gym fitness protection metalliques materiels individuelle avocats
#
# Topic 260 :
# televisions traditherapeutes occasion marche france animaux alimentaire comme reseau international
#
# Topic 261 :
# traditherapeutes agronomie pharmaceutique toutes financier batiment musique carreaux offre telephone
#
# Topic 262 :
# ligne emploi solaire renouvelable entreprise commissaires specialisee comptes abattoir prestation
#
# Topic 263 :
# emploi chambres gym fitness specialisee entreprise web ciment materiels industriels
#
# Topic 264 :
# carte recharge emploi societe tout beton gym fitness materiels professionnelle
#
# Topic 265 :
# emploi metalliques materiaux beton lieux magasins electriques solaire renouvelable benin
#
# Topic 266 :
# solaire renouvelable metalliques materiaux carte recharge entreprise benin chambres animale
#
# Topic 267 :
# metalliques energie materiaux entreprise specialisee abattoir viande ligne professionnelle carte
#
# Topic 268 :
# abattoir tout viande metalliques industriels materiaux solaire qualite renouvelable tous
#
# Topic 269 :
# abattoir viande technique benin chambres emploi web poulet construction equipements
#
# Topic 270 :
# professionnelle professionnelles tout management technique emploi securite courtier impression recherche
#
# Topic 271 :
# pizzeria patisserie cremerie pizzeriaglacier glacierglacier glacier professionnelle technique professionnelles viande
#
# Topic 272 :
# societe professionnelle scolaires distributeurs expert urbanisme aerien generale production transport
#
# Topic 273 :
# logistiques shipping scolaires routier societe distributeurs technique change mobilier consultant
#
# Topic 274 :
# technique tout installation chambres expert metalliques primaires societe bureau materiaux
#
# Topic 275 :
# operateurs telephoniques distributeurs shipping animale solution logistiques service bureau client
#
# Topic 276 :
# scolaires operateurs telephoniques change mobilier prestation consultant grossistes installation expert
#
# Topic 277 :
# cinemas aeroports alimentaire table depuis application plastique monetique cartographie veterinaire
#
# Topic 278 :
# aeroports dechets marche tri jus toute international leurs collecte recyclage
#
# Topic 279 :
# distributeurs animale prestation tout web controle generale site entreprise expert
#
# Topic 280 :
# scolaires animale distributeurs technique change mobilier solution service consultant client
#
# Topic 281 :
# urbanisme shipping architectesarchitecture amenagement design domaines animale humaines architecture ressources
#
# Topic 282 :
# installation animale archivage physique distributeurs professionnelle electricite societe professionnelles huile
#
# Topic 283 :
# magasins discotheques night accessoires archivage fitness physique article animale gym
#
# Topic 284 :
# archivage physique tout ged numerique urbanisme entreprise professionnelle document controle
#
# Topic 285 :
# publicite dietetiques production installation phytosanitaires ligne cosmetiques intrants entreprise pharmaceutiques
#
# Topic 286 :
# maroquinerie ligne publicite reparation etc ciment accessoires location agro securite
#
# Topic 287 :
# accessoires service location amincissement langue electriques production agro maternelle portable
#
# Topic 288 :
# publicite location ciment agro ligne transformation commercialisation electriques gym electricite
#
# Topic 289 :
# incendie gardiennage accessoires location langue prestation societe electronique maternelle industrie
#
# Topic 290 :
# electrotechnique industrie beton huile commercialisation societe electricite ligne abattoir amincissement
#
# Topic 291 :
# electrotechnique accessoires publicite langue production maternelle afrique prestation acces portable
#
# Topic 292 :
# publicite accessoires beton securite prestation portable specialisee industrie telephone langue
#
# Topic 293 :
# prefabriques publicite service electrotechnique incendie gardiennage lieux benin prestations agro
#
# Topic 294 :
# prefabriques prestation ligne afrique ciment location entreprises projets solution specialise
#
# Topic 295 :
# afrique huile accessoires publicite electricite plus lieux commercialisation dietetiques animale
#
# Topic 296 :
# beton imprimerie qualite amincissement port agro professionnelle installation lieux travaux
#
# Topic 297 :
# radiologie ordres salle instruments solaires batiment transformation faisons ordinateurs marque
#
# Topic 298 :
# ordres multimedias beton systemes laitiers evenements systeme jouets hotellerie structure
#
# Topic 299 :
# amincissement appels publicite afrique centre installation gardiennage incendie professionnelle industrie
#
# Topic 300 :
# amincissement entreprises agro appels transformation electricite acces prestation lieux imprimerie
#
# Topic 301 :
# beton acces fournisseur professionnelles appui afrique tout maritimes formation communication
#
# Topic 302 :
# port acces appui fournisseur faire savoir ouvre filiere excellence adduction
#
# Topic 303 :
# acces fournisseur minerale battery pile immigration projets bureaux eau ligne
#
# Topic 304 :
# minerale eau appui port internet installation afrique agro maritimes intrants
#
# Topic 305 :
# battery pile port appui afrique etc camion maritimes vehicules marque
#
# Topic 306 :
# vehicules port agro beton immigration afrique publicite vente occasion bureaux
#
# Topic 307 :
# tout battery pile immigration bureaux projets ligne ciment minerale internet
#
# Topic 308 :
#
# Topic 342 :
# ascenseurs cuisine sociale petroliers specialises vehicules domaine specialise hebergement depannage
#
# Topic 343 :
# aerien travaux gestion tous ascenseurs argent protection imprimerie benin intrants
#
# Topic 344 :
# sociale peinture plus etancheite chaudronnerie avitaillement depannage meches travaux consommables
#
# Topic 345 :
# ascenseurs achat agricole avitaillement video engrais intrants realisation conception entreprises
#
# Topic 346 :
# representants promotion specialises meubles qualite musees ascenseurs domaine sociale video
#
# Topic 347 :
# reparation etc diver aerien plus client petroliers ordinateurs taxi imprimerie
#
# Topic 348 :
# musees domaine intrants etancheite hebergement entreprises meubles engrais assistance tous
#
# Topic 349 :
# musees etancheite sociale representants etc consommables solution ascenseurs diver cuisine
#
# Topic 350 :
# musees vehicules livraison realisation parc reception reparation specialises conception demenagement
#
# Topic 351 :
# livraison etancheite intrants engrais cotonou demenagement agricole reception colis fabrication
#
# Topic 352 :
# studio imprimerie geolocalisation intrants plus specialise commercialisation forestiere sarl nettoyage
#
# Topic 353 :
# etancheite reparation etc intrants vehicules entreprises parc entreprise representants immobiliere
#
# Topic 354 :
# taxi vtc sarl tous aerien signalisation industriel route aussi poulet
#
# Topic 355 :
# miniere chaudronnerie livraison achat etc miniereextraction ressource taxi specialise sarl
#
# Topic 356 :
# miniere reparation plus etancheite argent traitement marque transformation industrielle nettoyage
#
# Topic 357 :
# etancheite realisation aerien taxi conception vtc solution chaudronnerie meubles nettoyage
#
# Topic 358 :
# diver marque aerien domaines taxi entreprise interieur vtc transformation agence
#
# Topic 359 :
# petroliers tous reparation etancheite signalisation route studio specialises commerce sociale
#
# Topic 360 :
# syndicats fleuristes intrants reparation autres agro chaudronnerie studio gros sociale
#
# Topic 361 :
# fleuristes psychiatre decoration studio etc plateforme electricite traitement achats parc
#
# Topic 362 :
# syndicats psychiatre traitement exportation lapin importation studio fabrication commercialisation agro
#
# Topic 363 :
# taxi intrants vtc chaudronnerie autres agro aerien reparation traitement entreprises
#
# Topic 364 :
# engrais parc transformation etc studio intrants petroliers agricole huile specialises
#
# Topic 365 :
# parc traitement autres primaire creation commerce electroniquereparation bois portable secondaire
#
# Topic 366 :
# diver engrais parc fourniture bio etancheite gros hebergement conception agro
#
# Topic 367 :
# intrants hebergement scieries etancheite cotonou specialises portable agence petroliers cloud
#
# Topic 368 :
# engrais autres realisation gros client vetements scieries travaux interieur solution
#
# Topic 369 :
# gros international commerce specialises marchandises engrais cotonou expertises importation details
#
# Topic 370 :
# parc scieries metallique primaire menuiserie interieur reparation secondaire vetements maternel
#
# Topic 371 :
# traitement etancheite taxi travaux reparation studio vtc hebergement parc gros
#
# Topic 372 :
# scieries parc traitement commercialisation agence qualite imprimerie diver vehicule engrais
#
# Topic 373 :
# scieries traitement client eaux menuiserie metallique taxi entreprise vtc tres
#
# Topic 374 :
# hebergement engrais etc signalisation route cloud client reception nettoyage batiment
#
# Topic 375 :
# client agence gros petroliers aussi accompagnement bien etancheite reparation inspection
#
# Topic 376 :
# fourniture petroliers autres station essence parc livraison etancheite site client
#
# Topic 377 :
# station essence interieur specialises plus petroliers coton marque travaux agence
#
# Topic 378 :
# fourniture specialises client parc scolaire achat religion culte domaine marchandises
#
# Topic 379 :
# traitement diver chaudronnerie vehicules commerce droit representants tous domaines station
#
# Topic 380 :
# gros decoration diver domaine taxi vtc specialises details financiere transformation
#
# Topic 381 :
# decoration station essence domaines taxi graphisme vtc hebergement electricite intrants
#
# Topic 382 :
# emballages marque engrais specialises client specialiste livraison sarl representants industriel
#
# Topic 383 :
# engrais gravure graphisme autres creation photographie vehicules studio specialisee activites
#
# Topic 384 :
# engrais reparation hebergement lapin vetements volaille autres entreprises plus porte
#
# Topic 385 :
# gravure station aussi sarl anglais essence droit transformation engrais tres
#
# Topic 386 :
# station cimenterie essence depuis creation design anglais tous traitement base
#
# Topic 387 :
# anglais graphisme francais cours emballages petroliers specialises volaille chaudronnerie fourniture
#
# Topic 388 :
# gravure gros toutes emballages engrais specialises general promotion tous enseignes
#
# Topic 389 :
# station route essence signalisation emballages cotonou offrons laitiers specialise digital
#
# Topic 390 :
# gravure station essence cosmetiquecosmetique enseignes and make africa soins maison
#
# Topic 391 :
# chocolaterie confiserie laitiers transformation client route gros livraison graphisme signalisation
#
# Topic 392 :
# agricole emballages gravure commerce cotonou graphisme meubles domaine creation client
#
# Topic 393 :
# droit travaux route salle creation promotion signalisation comptabilite avitaillement besoins
#
# Topic 394 :
# chocolaterie gravure decoration confiserie route coton petroliers client fourniture signalisation
#
# Topic 395 :
# vetements cosmetiquecosmetique and diver autres make importation lumineuses up exportation
#
# Topic 396 :
# cimenterie hebergement base financiere cloud comptable tres prestations marche plateforme
#
# Topic 397 :
# emballages fourniture maison expertises engrais diverses chocolaterie station confiserie droit
#
# Topic 398 :
# chocolaterie confiserie marchandises emballages colis cimenterie jeunes etc plastique maison
#
# Topic 399 :
# cimenterie cosmetiquecosmetique emballages engrais transformation aussi etude make up depuis
#
# Topic 400 :
# cosmetiquecosmetique cimenterie anglais representants machine marchandises decoration make chocolaterie interne
#
# Topic 401 :
# laitiers volaille premier agricole leurs africa plateforme reseau cimenterie traditionnelle
#
# Topic 402 :
# cosmetiquecosmetique laitiers volaille promotion soins homme solution scolaire toutes droit
#
# Topic 403 :
# neurologie maison chimiques livraison transformation metallique renouvelables coton energies propose
#
# Topic 404 :
# port egalement interne meubles toute promotion vetements besoins medecine emballages
#
# Topic 405 :
# chocolaterie neurologie confiserie traditionnelle cosmetiquecosmetique importation plateforme laitiers port coton
#
# Topic 406 :
# neurologie chocolaterie confiserie reeducation agricole graphisme massage marchandises agronomie machine
#
# Topic 407 :
# petroliers and graphisme traditionnelle colis toute fourniture montage gravure aussi
#
# Topic 408 :
# and interne medecine expertise chaudronnerie autres culte religion neurologie of
#
# Topic 409 :
# machine graphisme cimenterie representants chimiques photographie soins sans ordinateurs droit
#
# Topic 410 :
# and cimenterie domaine offrons bien financiere sarl egalement comptable of
#
# Topic 411 :
# laitiers machine maison interne achat importation graphisme domaines medecine sarl
#
# Topic 412 :
# culte religion chimiques fitness cimenterie reception gym financiere traditionnelle traitement
#
# Topic 413 :
# machine cimenterie metallique specialises tuyauterie anesthesistes reparation etc sous telephone
#
# Topic 414 :
# laitiers religion culte interne maison machine ainsi fitness gym medecine
#
# Topic 415 :
# traditionnelle laitiers egalement toutes vetements ainsi digitale cafe representants droit
#
# Topic 416 :
# cimenterie chaudronnerie laitiers bien agricole toles anesthesistes technology maison port
#
# Topic 417 :
# chaudronnerie domaines vetements marchandises offre solution public pharmaceutique financier autres
#
# Topic 418 :
# anesthesistes traiteur financier meubles activites web toutes coton design visa
#
# Topic 419 :
# marchandises cotonou realisation promotion consommables ainsi application evenements cafe immigration
#
# Topic 420 :
# coton laitiers cimenterie promotion bien vetements pharmaceutique jouets laboratoires etre
#
# Topic 421 :
# monetique domaine ainsi chimiques anesthesistes machine port vetements alimentaire cafe
#
# Topic 422 :
# anesthesistes savonnerie laitiers poulet monetique machine achats marchandises design technology
#
# Topic 423 :
# savonnerie domaine homme express multimedias poulet cosmetiquecosmetique emballages femme reseau
#
# Topic 424 :
# savonnerie anesthesistes metallique coton domaines ainsi plastique solaires marche toute
#
# Topic 425 :
# anesthesistes cafe alimentaire offrons maison aussi magazine international cacao egalement
#
# Topic 426 :
# monetique laitiers cimenterie visa savonnerie express bien preinscription digitale magazine
#
# Topic 427 :
# savonnerie monetique offrons promotion cimenterie chaudronnerie internationale chimiques expertises egalement
#
# Topic 428 :
# centrales achats savonnerie systemes photo chaudronnerie magazine maison renouvelables energies
#
# Topic 429 :
# chaudronnerie anesthesistes domaine ainsi jeunes realisation plastique express occasion industrielle
#
# Topic 430 :
# achats financier routiere centrales courrier cafe vetements base structure offrons
#
# Topic 431 :
# ordinateurs electroniques promotion alimentaire metallique telephones graphisme courrier agronomie scolaire
#
# Topic 432 :
# site ordinateurs domaine and multimedias meubles musique cafe design offrons
#
# Topic 433 :
# maison solaires tuyauterie comme renouvelables cotonou groupes energies specialiste plateforme
#
# Topic 434 :
# coton anglais leurs realisation agence juridique application representants anesthesistes mesure
#
# Topic 435 :
# achats centrales express cimenterie domestique alimentaire digital scolaire jeunes port
#
# Topic 436 :
# centrales achats beninoise etude egalement domestique enfants evenements laitiers jouets
#
# Topic 437 :
# express alimentaire routiere renouvelables electrique energies produit marchandises systeme domaines
#
# Topic 438 :
# cafe cacao express pharmaceutique traiteur port coton hotellerie maison scolaire
#
# Topic 439 :
# homme femme courrier alimentaire hotellerie chaudronnerie machine activites expertise comme
#
# Topic 440 :
# marche magazine multimedias activites leurs chirurgie ainsi laitiers digital agronomie
#
# Topic 441 :
# cafe promotion routiere magazine financier business cacao recyclage voiture multimedias
#
# Topic 442 :
# cimenterie pharmaceutique offrons traiteur bio domaine beninoise maison routiere ainsi
#
# Topic 443 :
# multimedias magazine scolaire offrons personnes depuis hygiene domaines plastique application
#
# Topic 444 :
# pharmaceutique traiteur multimedias agronomie jouets est courrier expertises hygiene ainsi
#
# Topic 445 :
# multimedias tuyauterie traiteur scolaire vetements toutes conception centrales achats instrument
#
# Topic 446 :
# multimedias besoins specialises autres mais petroliers photographie leurs droit machine
#
# Topic 447 :
# multimedias cafe genre digitale scolaire jouets marche domaine cacao huiles
#
# Topic 448 :
# toutes magazine domestique porte courrier multimedias digital graphisme metallurgique beninoise
#
# Topic 449 :
# musique photo plusieurs hotellerie faisons bijou investissement achats lunettes apres
#
# Topic 450 :
# pharmaceutique domestique international durable huiles gazvente multimedias digital maison base
#
# Topic 451 :
# domestique magazine gazvente pneus plan produit musique ordinateurs voiture technology
#
# Topic 452 :
# musique magazine animaux solaires appels panneaux digitale comme veterinaire biens
#
# Topic 453 :
# pharmaceutique specialiste digital hotellerie international etude site bio chimiques achat
#
# Topic 454 :
# multimedias metallurgique depuis animaux traiteur porte maison produit presse leurs
#
# Topic 455 :
# musique cafe multimedias vie achat beninoise design autres sans type
#
# Topic 456 :
# jouets scolaire financier hygiene business bio presse papeteriefourniture digitale pneus
#
# Topic 457 :
# controles jouets routiere voiture pharmaceutique marche pneus beninoise graphisme sol
#
# Topic 458 :
# agronomie jouets metallurgique produit chirurgie hotellerie professionnels type particuliers petite
#
# Topic 459 :
# sans site musiquevente traiteur achat pneus occasion cafe digitale telephone
#
# Topic 460 :
# traiteur domestique hotellerie salle photo hygiene evenements business visa hotel
#
# Topic 461 :
# toutes telecommunication installation genre vehicule comme vie systeme musique camion
#
# Topic 462 :
# agronomie domestique est haute depuis gazvente routiere promotion beninois comme
#
# Topic 463 :
# chimiques jouets danse toutes travers jeunes bio durable jus traiteur
#
# Topic 464 :
# domestique scolaire representants toute expertises gazvente tuyauterie courrier traiteur design
#
# Topic 465 :
# est pneus hotellerie chimiques occasion pneumatiquesvente voiture digitale photo danse
#
# Topic 466 :
# pneus pneumatiquesvente voiture jeunes faisons montage moderne leurs solaires routiere
#
# Topic 467 :
# tuyauterie finance agronomie application investissement centrales confection type hygiene structure
#
# Topic 468 :
# personnes bio hotel hotellerie coton expertises business design depuis cartographie
#
# Topic 469 :
# jouets alimentaire chaussuresvente comme scolaire routiere sans personnes surveillance solaires
#
# Topic 470 :
# agronomie metallurgique business financier gsm sans tropicaux toles accessoire propose
#
# Topic 471 :
# agronomie expertises base beninoise hotel culture audiovisuelle alimentaire financier systemes
#
# Topic 472 :
# multimedias jouets alimentaire massage metallique soins editeurs traiteur atelier meilleur
#
# Topic 473 :
# accompagnement jouets evenements veterinaire propriete beninoise activites intellectuelle consult plan
#
# Topic 474 :
# cartographie marbrerie domestique audiovisuelle systemes accompagnement travail motos confection secteur
#
# Topic 475 :
# traiteur cartographie orl marche sous musique marchandises frais recouvrement expertises
#
# Topic 476 :
# toute chaussuresvente controles digital application carrosserie disponible proposons centrales achats
#
# Topic 477 :
# veterinaire reseaux financier alimentaires toutes batiments ordinateurs coworking transfert animaux
#
# Topic 478 :
# sous carrosserie jouets group routiere scolaire graphisme plusieurs beninoise travers
#
# Topic 479 :
# cartographie investissement marche plastique application agronomie genre carreaux instruments travers
#
# Topic 480 :
# expertises hotellerie scolaire marbrerie dechets structure chez etude satisfaction inspection
#
# Topic 481 :
# hotellerie plastique systemes colis alarme leurs design canalisation innovante occasion
#
# Topic 482 :
# marbrerie plan education afin travers scolaire occasion chaussuresvente durable accessoire
#
# Topic 483 :
# tuyauterie jeunes evenements douanes application commissionnaires montage beninoise pneus animaux
#
# Topic 484 :
# agronomie orl est representants toles africaine faisons produit batiment danse
#
# Topic 485 :
# cartographie application etude orl mesure confection propose ameublementmobilier occasion droit
#
# Topic 486 :
# plastique toles investissement bancaire modevente france malady article comme digital
#
# Topic 487 :
# cartographie montage business evenements instrument table depuis travers fourniture motosvente
#
# Interprétation des topics terminée avec succès.

# %%
try:
    # Vérification de la DataFrame
    if 'topic_df' not in locals() or topic_df is None:
        raise ValueError("Le DataFrame 'topic_df' n'est pas défini.")
    if topic_df.empty:
        raise ValueError("Le DataFrame 'topic_df' est vide. Vérifiez vos données.")
    
    # Vérification des types numériques
    if not all(pd.api.types.is_numeric_dtype(topic_df[col]) for col in topic_df.columns):
        raise TypeError("Certaines colonnes de 'topic_df' ne sont pas numériques.")

    # Conversion en valeurs absolues (pour éliminer les valeurs négatives)
    to_positive = topic_df.applymap(lambda num: abs(num) if pd.notnull(num) else 0)

    # Identifier le topic dominant pour chaque livre
    dominant_topics = to_positive.idxmax(axis=1).to_frame().reset_index()

    # Regrouper les livres par topic
    books_by_topic = dominant_topics.groupby(0)["index"].apply(list).to_dict()

    # Vérification du résultat
    if not books_by_topic:
        print("Aucun regroupement n’a été trouvé.")
    else:
        print("=== Regroupement des livres par thème dominant ===\n")
        for key, value in books_by_topic.items():
            print(f"{key}:")
            print(", ".join(value))
            print()

    print("Regroupement terminé avec succès.")

except Exception as e:
    print(f"Une erreur est survenue lors du regroupement par topics : {e}")
# Out:
# /tmp/ipykernel_79451/3345333018.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   to_positive = topic_df.applymap(lambda num: abs(num) if pd.notnull(num) else 0)
# === Regroupement des livres par thème dominant ===
#
# Topic 1:
# CFPJ - MAN, A DIEU LE DERNIER MOT, ATARA SERVICE, AIRTECH-BENIN, FRED SERVICES, ABS TECHNOLOGIE GROUP, DGA STORE, PAPETERIE MODERNE CALAVI, AKONTA, TEC SARL, ALLMIGHTY EXPERTISES, ADJINOS CENTER, CIBLE INFORMATIQUE, 3J IT SERVICES, ABP TECHNOLOGIE, BENSOFT SERVICE, CHABO, DIGI SPHERE TECH GROUP, IFE AFRICA, M-TECHNOLOGIES, LA PASSION DE LA TECHNOLOGIE, 3D TELECOM BUSINESS CENTER, A.D. INFORMATIQUE SERVICE ET FILS, ABP SERVICE, ADEWALE CENTER, ADIS COMMUNICATION, AGEMA BENIN, AGRO GROUP DEVELOPPEMENT, ALL IN ONE BENIN, ARTHUR INFORMATIQUE, BEAUNACH BUSINESS CENTER CONSULTING, BELANCE BENIN SARL, BON SAMARITAIN FORMATION, CENTRE DE HAUTE TECHNOLOGIE AWOLOU ET FILS, CENTRE INFORMATIQUE LE LEADER, CENTRE MULTIMEDIA SANDY, CFAO Infrastructure, CH
# SIDI GLOBAL, GLOBAL MARITIME SURVEYS, AFRICA MARINE INSPECTIONS ET SERVICES LIMITED, ATLANTIC CONTROL GROUP INTER SA, BCF SARL, BEMACONST, CEM BENIN (COMPAGNIE DES EXPERTS MARITIMES DU BENIN), JLB EXPERTISES, LA TOUR DE BABELLE, SOTREXMA SARL, TCI-AFRICA BENIN, SERVICES INDUSTRIELS SIMI-T Sarl, AFRICA P & I, 2IN-SARL BENIN, ABBA MARINE, CIS SUPPLIES, PSC TEMA SHIPYARD LIMITED, SAMTI GROUPE, ADK SHIPPING AGENCY, CTR Sarl, COGIMAR-AB Sarl, GLOBAL TRANSIT, MARITIME AND PORTS CONSULTING, Broadline Services Ltd., CAMEL EXPRESS, International Freight Services, SAAT - AFRIQUE, SCHEKINA Bénin SARL, TED EMPIRE COMPANY, West Africa and China for Equipments, ABETRACO INTERNATIONAL SA, AD TRANS, ADEOLA ET FILS, AFG Group, AFRICA-TRANS, AFRIQUE GROUPAGE SA, AFRIQUE TRANSIT, AFRIQUE TRANSIT EXPRESS, ALBATROS COMPANY SAS, ALMO TRANSPORT, AMAL & FILS, APM GLOBAL LOGISTICS BENIN, ASFAA GROUP SARL, CAPOCH ET FILS Sarl, WEST AFRICA SHIPPING GROUP
#
# Topic 133:
# BeninNews, 24 HEURES AU BENIN, ACTUBENIN, AFRICA UNITED V-TEAM, AFRIQUE IMAGES, AGRI NETMEDIA, AKOEKO, ALERTE INFO, AWALE AFRIKI, BANOUTO, BENIN COULEURS, BENINFO247.COM, BLUE LIFE, BOULEVARD DES INFOS, BUT INFOS MAG, C2VSF, COURRIER DES AFRIQUES, DANY PRESSE, DECRYPTAGE INFOS, DIGNITE FEMININE HEBDO, DOKAWEB, ECHO DU JOUR, ETS LE FLEURON, BELLES ET ACTIVES, COSMOLAB HUB, L'AUTRE VISION, MAGAZINE IMPACT BUSINESS, CAPRICOM, AGRICOM
#
# Topic 134:
# A L'HEURE EXACTE, ABENI ET FILS, AFRICA PARURE, ALEKSEI SHOP, AMOUR D'OR BIJOUTERIE, BIJOUTERIE AFRICAINE, BIJOUTERIE CHEZ MCI, BIJOUTERIE DJAMA, BIJOUTERIE FOYER D'OR, BIJOUTERIE GUISSE DIAMANTAIRE, BIJOUTERIE JB ET FILS, BIJOUTERIE LE DIAMONO, BIJOUTERIE LE RENOUVEAU, BIJOUTERIE LINGOT D'OR, BIJOUTERIE TERANGA, BIJOUTERIE TERRANGA, EMINI BIJOUX, ENTREPRISE MINAS, ETS BIJOUTERIE LES ROIS, ETS CHEZ MA JOIE, ETS KIKE, ETS LA BIJOUTERIE, ETS LE FESTIN, ETS OLOUWATOGNI, ETS SINGBO ET FILS, GRISO SHOP BIJOUTERIE, LE COLISEE
#
# Topic 135:
# ASI SERVICE, BHS (BENIN HORIZON SERVICES)
#
# Topic 136:
# AMOUR D'ENFANT, ANIHOUVI LA MAISON DE LA PETITE ENFANCE, COMPLEXE SCOLAIRE (LA GLOIRE DIVINE)
#
# Topic 137:
#
# Topic 96:
# AGENCE DE PRODUCTION AUDIOVISUELLE, GAS PLUS, AGATHA DISTRIBUTION, MARAZZI GROUP GIUSEPPE ZANGRETTI BENIN, TOP SERVICES & CIE SARL, 2H, 2H BTP, A.2.S., ABIBOLA ALLADE SARL, ACG, ACIA 1, ADECO BENIN Sarl, ADEYINKA MARKET, ADJAMAT GROUP, ADONIS DROPSHOPING, AFRICA SERVICES, AFRICACEL TELECOMS, AFRIKA GLOBAL BENIN Sarl, AHAMS INVESTIMENT, AKPASSONOU MARKET SARL, AL-BACHAR ET FILS, ETS LUCANNE, JEHOVAH SCHAMMAH, ETS ROBKO, CHOUREIM STORE, FEMY BIEN ËTRE, AFRICA SOUND CITY, EL GUIBOR RECORD, JAYA SYMSEM PRODUCTION, STUDIO DE MUSIQUE, STUDIOS CIE DU SOL, TEAM KIMPORO MUSIC, CHRISTIAN TITANT PHOTOGRAPHY, LIOR PICTURES
#
# Topic 97:
# SIMI T SARL, DEENCO Consulting (DESIGN ENGINEERING CONSTRUCTION), 2OUS-TECH, ABRIS TELECOM, ABSU-CEP (AGENCE BENINOISE DU SERVICE UNIVERSEL DES COMMUNICATIONS ELECTRONIQUES ET DE LA POSTE), AGENCE POUR LE DEVELOPPEMENT DU NUMERIQUE, ALINK TELECOM, ANYXTECH SARL, AUTHENTIC VISION GROUPS TELECOM & POWER SARL - AVG-TP SARL, BLOLAB, BUSINESS CONTINUITY SERVICES, CHEZ LES JEUNES ET FILS, CINM, COMPLEXE POLYTECHNIQUE SAINT YVES, CONNECTEO BENIN SA, DIGITEL, ELECTRO 2000 COMPANY, ETS ESPACE TELECOM PLUS, ETS ETOILE DU MATIN, ETS FOLA STORE, ETS GENERAL SHARP, ETS GROUPE ACCESS, ETS GUEDES, ETS INTERNATIONAL SERVICE, ETS LA COMPETENCE INFORMATIQUE, ETS LA TOUZA, ETS LE CIEL OUVERT, ETS MAYO SERVICE
#
# Topic 98:
# ASFAA GROUP SARL, KENDRA SARL, NEW TRANS EXPRESS PLUS SARL, SATCO
#
# Topic 99:
# ETS AWAYA'S TRADE, ARSP-BENIN, ESPOIR EN L'ETERNEL, 3128 TECHNOLOGIES
#
# Regroupement terminé avec succès.

# %% [markdown]
# # Document similarity

# %%
best_recommended_pme("Je recherche une agence de communication digitale", vector, lsa, topic_df, 3)
# Out:
# Une erreur est survenue lors de la génération des recommandations : Incompatible dimension for X and Y matrices: X.shape[1] == 10696 while Y.shape[1] == 487
# []

# %%
search_df = pd.DataFrame(data=["Je recherche une agence de communication digitale"], columns=["summary"])
tokenized_book = tokenizer(search_df)
without_stopwords = stopwords_remover(tokenized_book)
without_punctuation = punctuation_remover(without_stopwords)
tagged_words = pos_tagger(without_punctuation)
lemmatized_words = lemmatizer(tagged_words)
vec = vector.transform(lemmatized_words)
vec
lsa.transform(vec)
vec
# Out:
# /home/overwatch2009/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but TruncatedSVD was fitted with feature names
#   warnings.warn(
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (1, 10696)>
